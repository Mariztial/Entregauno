# %% [markdown]
# ruta db
#
#
#
# ```
# # Tiene formato de código
# /content/drive/MyDrive/Colab_Notebooks/BASEDEDATOS1/BASE_1.csv
# ```

# %%
import pandas as pd
datos=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/BASEDEDATOS1/db_load.csv")
datos
# Out:
#      Index            Country     Scope       Jurisdiction Type of Law  \
# 0        1        Afghanistan  National        Afghanistan         Ban
# 1        2            Albania  National            Albania         Ban
# 2        3            Algeria  National            Algeria       Other
# 3        4            Andorra     State            Andorra         Ban
# 4        5  Antigua & Barbuda  National  Antigua & Barbuda         Ban
# ..     ...                ...       ...                ...         ...
# 989    990            Vanuatu  National            Vanuatu         Ban
# 990    991            Vietnam     Local   Ho Chi Minh City         Ban
# 991    992            Vietnam  National            Vietnam         Fee
# 992    993              Yemen  National              Yemen         Ban
# 993    994           Zimbabwe  National           Zimbabwe         Ban
#
#     Product Type                                     Application Ordinance  \
# 0            Bag                                         Unknown         -
# 1            Bag                                         Unknown         -
# 2            Bag                                          Import         -
# 3            Bag                                         Unknown         -
# 4            Bag  Retail, Manufacture, Distribution, Import, Use      link
# ..           ...                                             ...       ...
# 989        Straw                                      Restaurant         -
# 990          Bag                                         Unknown         -
# 991          Bag                                          Retail         -
# 992          Bag                                         Unknown         -
# 993          Bag                                         Unknown         -
#
#                                 Hyperlink to Ordinance
# 0    https://docs.google.com/forms/d/e/1FAIpQLScYxy...
# 1    https://docs.google.com/forms/d/e/1FAIpQLScYxy...
# 2    https://docs.google.com/forms/d/e/1FAIpQLScYxy...
# 3    https://docs.google.com/forms/d/e/1FAIpQLScYxy...
# 4    http://legalaffairs.gov.ag/pdf/bills/External_...
# ..                                                 ...
# 989  https://docs.google.com/forms/d/e/1FAIpQLScYxy...
# 990  https://docs.google.com/forms/d/e/1FAIpQLScYxy...
# 991  https://docs.google.com/forms/d/e/1FAIpQLScYxy...
# 992  https://docs.google.com/forms/d/e/1FAIpQLScYxy...
# 993  https://docs.google.com/forms/d/e/1FAIpQLScYxy...
#
# [994 rows x 9 columns]

# %%
import pandas as pd
datos=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/BASEDEDATOS1/db_load.csv")
#print(datos)
datos.drop(["Hyperlink to Ordinance"], axis=1, inplace=True)
datos.drop(["Ordinance"], axis=1, inplace=True)
datos
df_filtered = datos[datos["Product Type"] != "Straw"]
df_filtered
# Out:
#      Index            Country     Scope       Jurisdiction Type of Law  \
# 0        1        Afghanistan  National        Afghanistan         Ban
# 1        2            Albania  National            Albania         Ban
# 2        3            Algeria  National            Algeria       Other
# 3        4            Andorra     State            Andorra         Ban
# 4        5  Antigua & Barbuda  National  Antigua & Barbuda         Ban
# ..     ...                ...       ...                ...         ...
# 988    989            Vanuatu  National            Vanuatu         Ban
# 990    991            Vietnam     Local   Ho Chi Minh City         Ban
# 991    992            Vietnam  National            Vietnam         Fee
# 992    993              Yemen  National              Yemen         Ban
# 993    994           Zimbabwe  National           Zimbabwe         Ban
#
#     Product Type                                     Application
# 0            Bag                                         Unknown
# 1            Bag                                         Unknown
# 2            Bag                                          Import
# 3            Bag                                         Unknown
# 4            Bag  Retail, Manufacture, Distribution, Import, Use
# ..           ...                                             ...
# 988          Bag                                         Unknown
# 990          Bag                                         Unknown
# 991          Bag                                          Retail
# 992          Bag                                         Unknown
# 993          Bag                                         Unknown
#
# [961 rows x 7 columns]

# %% [markdown]
# Lo que hicimos fue elminar la columna de los hipervínculos, que no nos interesaba en nuestra investigación. También filtramos todo lo que no eran bolsas en la columna del tipo de producto. Además, eliminamos la columna de ordinance.
