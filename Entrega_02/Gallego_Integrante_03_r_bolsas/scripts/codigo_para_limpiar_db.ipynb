# %% [markdown]
# Base de datos: Reciclaje de plastico en Regiones

# %%
import pandas as pd
import seaborn as sns

# %%
r_bolsas = pd.read_excel ("/content/drive/MyDrive/Reciclaje de envases plásticos por región.xlsx")

# %%
r_bolsas.head ()
# Out:
#                 Regiones  Plásticos  Puntos verdes (Ton/mes)  \
# 0  XV Arica y Parinacota       0.77                      0.6
# 1             I Tarapacá       0.72                      NaN
# 2         II Antofagasta       0.88                      9.7
# 3            III Atacama       0.93                     21.0
# 4            IV Coquimbo       0.79                      2.8
#
#    Puntos limpios (Ton/mes)  Centros de acopio (Ton/mes)
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       0.5                        602.0
# 3                       0.0                        659.0
# 4                      59.0                        831.0

# %%
columnas_a_eliminar = ("Centros de acopio (Ton/mes)")

# %%
r_bolsas = r_bolsas.drop(columnas_a_eliminar, axis=1)

# %%
print("\nr_bolsas después de eliminar las columnas:")
print(r_bolsas)
# Out:
# r_bolsas después de eliminar las columnas:
#                                  Regiones  Plásticos  Puntos verdes (Ton/mes)  \
# 0                   XV Arica y Parinacota       0.77                      0.6
# 1                              I Tarapacá       0.72                      NaN
# 2                          II Antofagasta       0.88                      9.7
# 3                             III Atacama       0.93                     21.0
# 4                             IV Coquimbo       0.79                      2.8
# 5                            V Valparaíso       0.76                      4.6
# 6                    Región Metropolitana       0.74                    108.0
# 7        VI Libertador Bernardo O'Higgins       0.82                      NaN
# 8                               VII Maule       0.72                     24.0
# 9                             VIII Biobío       0.79                     39.0
# ...
