# %%
import pandas as pd
data = pd.read_csv('BASE DATOS 1.csv')
data.head()
# Out:
#    Index            Country     Scope       Jurisdiction Type of Law  \
# 0      1        Afghanistan  National        Afghanistan         Ban
# 1      2            Albania  National            Albania         Ban
# 2      3            Algeria  National            Algeria       Other
# 3      4            Andorra     State            Andorra         Ban
# 4      5  Antigua & Barbuda  National  Antigua & Barbuda         Ban
#
#   Product Type                                     Application
# 0          Bag                                         Unknown
# 1          Bag                                         Unknown
# 2          Bag                                          Import
# 3          Bag                                         Unknown
# 4          Bag  Retail, Manufacture, Distribution, Import, Use

# %% [markdown]
# Definimos las variables que van a ser necesarias para construir las visualizaciones.

# %%
country_column = 'Country'
type_of_law_column = 'Type of Law'
application_column = 'Application'

# %% [markdown]
# Tuve que dejar todos los datos de las variables en mayúscula, ya que habían datos en minúscula y otras en mayúscula, y se repetían en las vizualizaciones.

# %%
data[country_column]= data[country_column].str.capitalize()
data[type_of_law_column]= data[type_of_law_column].str.capitalize()
data[application_column]= data[application_column].str.capitalize()

# %% [markdown]
# Acontinuación, intentamos ordenar los datos correspondientes a la variable de aplicación. Dejamos que los datos que se repiten más de una vez aparezcan, y aquellos que se repiten solo una vez, los agrupamos en la categoría de "Otros".

# %%
combination_app = data.groupby(['Application']).size().reset_index(name='Cantidad')
combination_app
grafico = combination_app[combination_app["Cantidad"]>1]
otros = combination_app[combination_app["Cantidad"]==1]["Cantidad"].sum()

# %%
nueva_fila = {"Application": "otros", "Cantidad": otros}
grafico = grafico.append(nueva_fila, ignore_index=True)
grafico
# Out:
# /var/folders/gw/1_gt3bqj57d6dgvt4fwl1z89zh59z8/T/ipykernel_44240/1946028028.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   grafico = grafico.append(nueva_fila, ignore_index=True)
#                                        Application  Cantidad
# 0                                       Government        14
# 1                                           Import         4
# 2                                      Manufacture         4
# 3                              Manufacture, import         4
# 4                                 Manufacture, use         2
# 5                                       Restaurant       140
# 6                               Restaurant, retail        37
# 7                                           Retail       432
# 8                              Retail, manufacture         8
# 9        Retail, manufacture, distribution, import         5
# 10  Retail, manufacture, distribution, import, use         3
# 11                     Retail, manufacture, import         3
# 12                Retail, manufacture, import, use         3
# 13                              Retail, restaurant        99
# 14                                        Retailer         7
# 15                                         Unknown       180
# 16                                           otros        12

# %%
combination_coun = data.groupby(['Country']).size().reset_index(name='cantidad')
combination_coun
# Out:
#                Country  cantidad
# 0          Afghanistan         1
# 1              Albania         1
# 2              Algeria         1
# 3              Andorra         1
# 4    Antigua & barbuda         1
# ..                 ...       ...
# 142         Uzbekistan         1
# 143            Vanuatu         1
# 144            Vietnam         2
# 145              Yemen         1
# 146           Zimbabwe         1
#
# [147 rows x 2 columns]

# %% [markdown]
# Ponemos sólo los países que se repitan más de tres veces.

# %%
min_count = 3
combination_coun_filtered = combination_coun[combination_coun['cantidad'] >= min_count]
print(combination_coun_filtered)
# Out:
#             Country  cantidad
# 5         Argentina         6
# 7         Australia        12
# 18           Brazil         4
# 25           Canada        25
# 29            Chile         4
# 47           France         4
# 59         Honduras         3
# 62            India        13
# 63        Indonesia         7
# 94          Myanmar         3
# 98      New zealand         3
# 104        Pakistan         4
# 109     Philippines        38
# 130          Taiwan         3
# 139  United kingdom        10
# 140   United states       677

# %% [markdown]
# Creamos la variable de "repetidos", correspondiente a los países que se repiten.

# %%
repetidos = data[data["Country"].isin(combination_coun_filtered["Country"])]
repetidos
# Out:
#      Index        Country      Scope              Jurisdiction Type of Law  \
# 5        6      Argentina      Local         Buenos Aires City         Ban
# 6        7      Argentina      Local                 El Bolson         Ban
# 7        8      Argentina      Local               El Calafate         Ban
# 8        9      Argentina      State     Buenos Aires Province         Ban
# 9       10      Argentina      State           Chubut Province         Ban
# ..     ...            ...        ...                       ...         ...
# 949    982  United states  Territory            American Samoa         Ban
# 950    983  United states  Territory                      Guam         Ban
# 951    984  United states  Territory  Northern Mariana Islands         Ban
# 952    985  United states  Territory               Puerto Rico         Ban
# 953    986  United states  Territory       U.S. Virgin Islands         Ban
#
#     Product Type Application
# 5            Bag     Unknown
# 6            Bag      Retail
# 7            Bag     Unknown
# 8            Bag      Retail
# 9            Bag      Retail
# ..           ...         ...
# 949          Bag      Retail
# 950          Bag      Retail
# 951          Bag      Retail
# 952          Bag      Retail
# 953          Bag      Retail
#
# [816 rows x 7 columns]

# %% [markdown]
# Creamos las siguientes variables para poder hacer la visualización, combinando los tipos de leyes con los países.

# %%
paises_con_ban = repetidos[repetidos["Type of Law"]=="Ban"].groupby("Country").count()["Type of Law"].reset_index()
paises_con_fee = repetidos[repetidos["Type of Law"]=="Fee"].groupby("Country").count()["Type of Law"].reset_index()
paises_con_banfee = repetidos[repetidos["Type of Law"]=="Ban+Fee"].groupby("Country").count()["Type of Law"].reset_index()

# %%
paises_con_ban["Tipo de ley"] = "Ban"
paises_con_fee["Tipo de ley"] = "Fee"
paises_con_banfee["Tipo de ley"] = "Ban+Fee"

# %% [markdown]
# Ponemos los datos que vamos a usar para el gráfico.

# %%
datos = paises_con_ban.append(paises_con_fee, ignore_index=True).append(paises_con_banfee, ignore_index=True)
datos
# Out:
# /var/folders/gw/1_gt3bqj57d6dgvt4fwl1z89zh59z8/T/ipykernel_44240/2379708918.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datos = paises_con_ban.append(paises_con_fee, ignore_index=True).append(paises_con_banfee, ignore_index=True)
#            Country  Type of Law Tipo de ley
# 0        Argentina            6         Ban
# 1        Australia            8         Ban
# 2           Brazil            4         Ban
# 3           Canada           21         Ban
# 4            Chile            4         Ban
# 5           France            4         Ban
# 6         Honduras            3         Ban
# 7            India           13         Ban
# 8        Indonesia            3         Ban
# 9          Myanmar            3         Ban
# 10     New zealand            3         Ban
# 11        Pakistan            4         Ban
# 12     Philippines           35         Ban
# 13          Taiwan            1         Ban
# 14  United kingdom            7         Ban
# 15   United states          438         Ban
# 16       Australia            1         Fee
# 17          Canada            3         Fee
# 18       Indonesia            4         Fee
# 19     Philippines            1         Fee
# 20  United kingdom            3         Fee
# 21   United states           19         Fee

# %% [markdown]
# Ponemos los códigos para crear el gráfico.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# data
x= datos["Country"].tolist()
y= datos["Type of Law"].tolist()
z= datos["Tipo de ley"].tolist()

# create pandas dataframe
data_list = pd.DataFrame(
    {'x_axis': x,
     'y_axis': y,
     'category': z
    })

# change size of data points
minsize = min(data_list['y_axis'])
maxsize = max(data_list['y_axis'])

# scatter plot
sns.catplot(x="x_axis", y="y_axis", kind="swarm", hue="category",sizes=(minsize*100, maxsize*100), data=data_list)
plt.grid()
# Out:
# /Library/Python/3.9/site-packages/seaborn/categorical.py:3370: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 23
#      20 maxsize = max(data_list['y_axis'])
#      22 # scatter plot
# ---> 23 sns.catplot(x="x_axis", y="y_axis", kind="swarm", hue="category",sizes=(minsize*100, maxsize*100), data=data_list)
#      24 plt.grid()
#
# File /Library/Python/3.9/site-packages/seaborn/categorical.py:2869, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2866     if plot_kws.setdefault("linewidth", 0) is None:
#    2867         plot_kws["linewidth"] = np.sqrt(plot_kws["s"]) / 10
# -> 2869     p.plot_swarms(
#    2870         dodge=dodge,
#    2871         color=color,
#    2872         warn_thresh=warn_thresh,
#    2873         plot_kws=plot_kws,
#    2874     )
#    2876 elif kind == "box":
#    2878     plot_kws = kwargs.copy()
#
# File /Library/Python/3.9/site-packages/seaborn/categorical.py:581, in _CategoricalPlotter.plot_swarms(self, dodge, color, warn_thresh, plot_kws)
#     578         points.draw = draw.__get__(points)
#     580 _draw_figure(ax.figure)
# --> 581 self._configure_legend(ax, _scatter_legend_artist, plot_kws)
#
# File /Library/Python/3.9/site-packages/seaborn/categorical.py:419, in _CategoricalPlotter._configure_legend(self, ax, func, common_kws, semantic_kws)
#     416     show_legend = bool(self.legend)
#     418 if show_legend:
# --> 419     self.add_legend_data(ax, func, common_kws, semantic_kws=semantic_kws)
#     420     handles, _ = ax.get_legend_handles_labels()
#     421     if handles:
#
# File /Library/Python/3.9/site-packages/seaborn/_base.py:1270, in VectorPlotter.add_legend_data(self, ax, func, common_kws, attrs, semantic_kws)
#    1268     if attr in kws:
#    1269         level_kws[attr] = kws[attr]
# -> 1270 artist = func(label=label, **{"color": ".2", **common_kws, **level_kws})
#    1271 if _version_predates(mpl, "3.5.0"):
#    1272     if isinstance(artist, mpl.lines.Line2D):
#
# File /Library/Python/3.9/site-packages/seaborn/utils.py:927, in _scatter_legend_artist(**kws)
#     924     else:
#     925         line_kws["markeredgecolor"] = edgecolor
# --> 927 return mpl.lines.Line2D([], [], **line_kws)
#
# File /Library/Python/3.9/site-packages/matplotlib/lines.py:407, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     403 self.set_markeredgewidth(markeredgewidth)
#     405 # update kwargs before updating data to give the caller a
#     406 # chance to init axes (and hence unit support)
# --> 407 self._internal_update(kwargs)
#     408 self.pickradius = pickradius
#     409 self.ind_offset = 0
#
# File /Library/Python/3.9/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File /Library/Python/3.9/site-packages/matplotlib/artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'sizes'

# %% [markdown]
# Definimos los ejes.

# %%
x= datos["Country"].tolist()
y= datos["Type of Law"].tolist()
z= datos["Tipo de ley"].tolist()
len(z)
sns.scatterplot(data=datos, x="Type of Law", y="Country", hue="Tipo de ley")
# Out:
# <Axes: xlabel='Type of Law', ylabel='Country'>

# %% [markdown]
# Hacemos un resumen de los tipos de leyes que existen, y cuáles son más usadas.

# %%
combination_tl = data.groupby(['Type of Law']).size().reset_index(name='Cantidad')
combination_tl
# Out:
#       Type of Law  Cantidad
# 0             Ban       663
# 1         Ban+fee       233
# 2  Ban/fee hybrid         2
# 3   Comprehensive         2
# 4             Fee        53
# 5           Other         8

# %%
combination_tl = data.groupby(['Type of Law', 'Application']).size().reset_index(name='Cantidad')
min_count = 3
combination_tl_filtered = combination_tl[combination_tl['Cantidad'] >= min_count]
combination_tl_filtered
# Out:
#    Type of Law                                     Application  Cantidad
# 2          Ban                                      Government        14
# 5          Ban                                     Manufacture         3
# 8          Ban                             Manufacture, import         3
# 10         Ban                                      Restaurant       140
# 12         Ban                              Restaurant, retail        37
# 13         Ban                                          Retail       188
# 17         Ban                             Retail, manufacture         7
# 18         Ban       Retail, manufacture, distribution, import         5
# 19         Ban  Retail, manufacture, distribution, import, use         3
# 21         Ban                Retail, manufacture, import, use         3
# 22         Ban                              Retail, restaurant        88
# 24         Ban                                        Retailer         3
# 25         Ban                                         Unknown       151
# 27     Ban+fee                                          Retail       211
# 30     Ban+fee                              Retail, restaurant        11
# 31     Ban+fee                                         Unknown         9
# 33         Fee                                          Retail        31
# 34         Fee                                        Retailer         4
# 35         Fee                                         Unknown        18

# %%
from matplotlib import pyplot as plt
import seaborn as sns
combination_tl_filtered.groupby('Type of Law').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Y de esta manera, logramos obtener dos visualizaciones que nos hablan sobre las legislaciones existentes en cuanto al uso de bolsas plásticas en diferentes países.

# %%
Retail= data[data["Application"]=="Retail"]
Retail
# Out:
#      Index        Country      Scope              Jurisdiction Type of Law  \
# 6        7      Argentina      Local                 El Bolson         Ban
# 8        9      Argentina      State     Buenos Aires Province         Ban
# 9       10      Argentina      State           Chubut Province         Ban
# 10      11      Argentina      State          Mendoza Province         Ban
# 11      12          Aruba      Local                     Aruba         Ban
# ..     ...            ...        ...                       ...         ...
# 950    983  United states  Territory                      Guam         Ban
# 951    984  United states  Territory  Northern Mariana Islands         Ban
# 952    985  United states  Territory               Puerto Rico         Ban
# 953    986  United states  Territory       U.S. Virgin Islands         Ban
# 958    992        Vietnam   National                   Vietnam         Fee
#
#     Product Type Application
# 6            Bag      Retail
# 8            Bag      Retail
# 9            Bag      Retail
# 10           Bag      Retail
# 11           Bag      Retail
# ..           ...         ...
# 950          Bag      Retail
# 951          Bag      Retail
# 952          Bag      Retail
# 953          Bag      Retail
# 958          Bag      Retail
#
# [432 rows x 7 columns]

# %%
Nacional_previa= Retail[Retail["Jurisdiction"]== Retail["Country"]]
Nacional = Nacional_previa[Nacional_previa["Product Type"]=="Bag"]
Nacional
# Out:
#      Index      Country     Scope Jurisdiction Type of Law Product Type  \
# 11      12        Aruba     Local        Aruba         Ban          Bag
# 24      26      Austria     State      Austria         Ban          Bag
# 74      77        Chile     Local        Chile         Ban          Bag
# 78      81        China  National        China         Fee          Bag
# 80      83     Colombia  National     Colombia     Ban+fee          Bag
# 81      84        Congo  National        Congo     Ban+fee          Bag
# 86      89      Denmark  National      Denmark         Fee          Bag
# 138    142       Israel  National       Israel     Ban+fee          Bag
# 165    170      Moldova  National      Moldova         Ban          Bag
# 166    171       Monaco  National       Monaco         Ban          Bag
# 173    178      Namibia  National      Namibia         Ban          Bag
# 174    179        Nepal  National        Nepal         Ban          Bag
# 175    180  Netherlands  National  Netherlands         Ban          Bag
# 230    235       Poland  National       Poland         Fee          Bag
# 249    254        Spain  National        Spain         Ban          Bag
# 251    256       Sweden  National       Sweden         Ban          Bag
# 252    257       Sweden  National       Sweden         Fee          Bag
# 255    260       Taiwan  National       Taiwan     Ban+fee          Bag
# 958    992      Vietnam  National      Vietnam         Fee          Bag
#
#     Application
# 11       Retail
# 24       Retail
# 74       Retail
# 78       Retail
# 80       Retail
# 81       Retail
# 86       Retail
# 138      Retail
# 165      Retail
# 166      Retail
# 173      Retail
# 174      Retail
# 175      Retail
# 230      Retail
# 249      Retail
# 251      Retail
# 252      Retail
# 255      Retail
# 958      Retail

# %%
(async () => {

    const topology = await fetch(
        'https://code.highcharts.com/mapdata/custom/world.topo.json'
    ).then(response => response.json());

    const data = await fetch(
        'https://cdn.jsdelivr.net/gh/highcharts/highcharts@v7.0.0/samples/data/world-population-density.json'
    ).then(response => response.json());
# Out:
#   Cell In[19], line 1
#     (async () => {
#      ^
# SyntaxError: invalid syntax

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Type of Law'].value_counts()
    for x_label, grp in Nacional.groupby('Scope')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Scope')
_ = plt.ylabel('Type of Law')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Product Type'].value_counts()
    for x_label, grp in Nacional.groupby('Type of Law')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Type of Law')
_ = plt.ylabel('Product Type')
